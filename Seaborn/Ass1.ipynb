# %% [markdown]
# <b><h2>Assignment No : 4.1</h2></b>
# <h4><b>Problem Statement :</b></h4>
# <b><i>Write a Python program to create a plot to get a general Statistics of Iris data. (Using the dataset “iris.csv”)</i></b><br>
# <hr>
# <br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
iris.describe().plot(kind="area",fontsize=15,figsize =(20,8), table=True)
plt.xlabel("Statistics")
plt.ylabel("value")
plt.title("General Statistics of iris dataset")
# Out:
# Text(0.5, 1.0, 'General Statistics of iris dataset')

# %% [markdown]
# <b><h2>Assignment No : 4.2</h2></b>
# <h4><b>Problem Statement :</b></h4>
# <b><i>Write a Python program to create a graph to find relationship between the sepal length and width. (Using the dataset “iris.csv”)</i></b><br>
# <hr>
# <br>

# %%
sns.scatterplot(x=iris.sepal_length, y= iris.sepal_width, hue=iris.species)
plt.grid()

# %% [markdown]
# <b><h2>Assignment No : 4.3</h2></b>
# <h4><b>Problem Statement :</b></h4>
# <b><i>Write a Python program to create a join plot using "hexbin" to describe individual distributions on the same plot between Sepal length and Sepal width. (Using the dataset “iris.csv”)</i></b><br>
# <hr>
# <br>

# %%
sns.jointplot(x=iris.sepal_length, y= iris.sepal_width,kind="hex")

# %% [markdown]
# <b><h2>Assignment No : 4.4</h2></b>
# <h4><b>Problem Statement :</b></h4>
# <b><i>Write a Python program to create a join plot and add regression and kernel density fits using "reg" to describe individual distributions on the same plot between Sepal length and Sepal width. (Using the dataset “iris.csv”)</i></b><br>
# <hr>
# <br>

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind='reg')
plt.show()

# %% [markdown]
# <b><h2>Assignment No : 4.5</h2></b>
# <h4><b>Problem Statement :</b></h4>
# <b><i>Write a Python program to find the correlation between variables of iris data. Also create a heat map using Seaborn to present their relations (Using the dataset “iris.csv”)</i></b><br>
# <hr>
# <br>

# %%
X = iris.iloc[:, 1:5]
numeric_columns = iris.select_dtypes(include=['float64', 'int64'])
corr = numeric_columns.corr()
print(corr)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr,cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True,
linewidths=.5)
# Out:
# <Axes: >
