# %% [markdown]
# <b><h2>Assignment No : 01</h2></b>
# <h4><b>Problem Statement :</b></h4>
# <b><i>Go through position_salaries.csv file and show that it is not following linear regression and can be best modelled with polynomial regression. It consists of only two fields’ position and salary .</i></b><br>
# <hr>
# <br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures

# %%
df=pd.read_csv("D:\CSE_2021_22\Position_Salaries.csv")
x=df[['Level']].values
y=df['Salary'].values

# %%
lin_reg=LinearRegression().fit(x,y)
y_pred=lin_reg.predict(x)
plt.scatter(x,y,color="blue")
plt.plot(x,y_pred,"r-")
plt.title('Linear Regression')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
print("R2 score for linear regression",metrics.r2_score(y,y_pred))
# Out:
# R2 score for linear regression 0.6690412331929895

# %% [markdown]
# <br><br><br>

# %%
poly_reg=PolynomialFeatures(degree=5)
xpoly=poly_reg.fit_transform(x)
lin_reg=LinearRegression().fit(xpoly,y)
y_pred=lin_reg.predict(xpoly)
plt.scatter(x,y,color="blue")
plt.plot(x,y_pred,"r-")
plt.title('Polinomial Regression')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
print("R2 score for polynomial regression",metrics.r2_score(y,y_pred))
# Out:
# R2 score for polynomial regression 0.9997969027099753
