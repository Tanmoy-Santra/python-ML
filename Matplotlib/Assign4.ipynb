# %% [markdown]
# <b><h2>Assignment No : 04</h2></b>
# <h4><b>Problem Statement :</b></h4>
# <b><i>Take the dirtydata.csv as an input and plot the box-plot for the column duration and find out how many outliers are there ?</i></b>
# <hr>
# <br>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('D:\CSE_2021_22\dirtydata.csv')
df = df.dropna(subset=['Duration'])
x=df['Duration']
plt.boxplot(x)
plt.show()

# %% [markdown]
# <h3>There are 3 outliers</h3>
